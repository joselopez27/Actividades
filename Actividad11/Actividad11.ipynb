# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import ode
import math


def fun(t,z ,gamma , w , delta , alfa , beta):
    """
    Right hand side of the differential equations
      dx/dt = -omega * y
      dy/dt = omega * x
    """
    x, y = z
    f = [y, gamma*math.cos(w*t)-delta*y-alfa*x-beta*x**3]
    return f

# Create an `ode` instance to solve the system of differential
# equations defined by `fun`, and set the solver method to 'dop853'.
solver = ode(fun)
solver.set_integrator('dop853')

# Give the value of omega to the solver. This is passed to
# `fun` when the solver calls it.
gamma = .2
w = 1.2
delta = 0.3
alfa = -1
beta = 1
solver.set_f_params(gamma,w,delta,alfa,beta)

# Set the initial value z(0) = z0.
t0 = 0.0
z0 = [1, 0]
solver.set_initial_value(z0, t0)

# Create the array `t` of time values at which to compute
# the solution, and create an array to hold the solution.
# Put the initial value in the solution array.
t1 = 70
N = 2000
t = np.linspace(t0, t1, N)
sol = np.empty((N, 2))
sol[0] = z0

# Repeatedly call the `integrate` method to advance the
# solution to time t[k], and save the solution in sol[k].
k = 1
while solver.successful() and solver.t < t1:
    solver.integrate(t[k])
    sol[k] = solver.y
    k += 1

# Plot the solution...
plt.plot(t, sol[:,0], label='gamma = 0.2')
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('t')
plt.ylabel('x')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import ode
import math


def fun(t,z ,gamma , w , delta , alfa , beta):
    """
    Right hand side of the differential equations
      dx/dt = -omega * y
      dy/dt = omega * x
    """
    x, y = z
    f = [y, gamma*math.cos(w*t)-delta*y-alfa*x-beta*x**3]
    return f

# Create an `ode` instance to solve the system of differential
# equations defined by `fun`, and set the solver method to 'dop853'.
solver = ode(fun)
solver.set_integrator('dop853')

# Give the value of omega to the solver. This is passed to
# `fun` when the solver calls it.
gamma = .35
w = 1.2
delta = 0.3
alfa = -1
beta = 1
solver.set_f_params(gamma,w,delta,alfa,beta)

# Set the initial value z(0) = z0.
t0 = 0.0
z0 = [1, 0]
solver.set_initial_value(z0, t0)

# Create the array `t` of time values at which to compute
# the solution, and create an array to hold the solution.
# Put the initial value in the solution array.
t1 = 70
N = 2000
t = np.linspace(t0, t1, N)
sol1 = np.empty((N, 2))
sol1[0] = z0

# Repeatedly call the `integrate` method to advance the
# solution to time t[k], and save the solution in sol[k].
k = 1
while solver.successful() and solver.t < t1:
    solver.integrate(t[k])
    sol1[k] = solver.y
    k += 1

# Plot the solution...
plt.plot(t, sol1[:,0], label='Gamma = 0.35')
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('t')
plt.ylabel('x')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import ode
import math


def fun(t,z ,gamma , w , delta , alfa , beta):
    """
    Right hand side of the differential equations
      dx/dt = -omega * y
      dy/dt = omega * x
    """
    x, y = z
    f = [y, gamma*math.cos(w*t)-delta*y-alfa*x-beta*x**3]
    return f

# Create an `ode` instance to solve the system of differential
# equations defined by `fun`, and set the solver method to 'dop853'.
solver = ode(fun)
solver.set_integrator('dop853')

# Give the value of omega to the solver. This is passed to
# `fun` when the solver calls it.
gamma = .50
w = 1.2
delta = 0.3
alfa = -1
beta = 1
solver.set_f_params(gamma,w,delta,alfa,beta)

# Set the initial value z(0) = z0.
t0 = 0.0
z0 = [1, 0]
solver.set_initial_value(z0, t0)

# Create the array `t` of time values at which to compute
# the solution, and create an array to hold the solution.
# Put the initial value in the solution array.
t1 = 70
N = 2000
t = np.linspace(t0, t1, N)
sol2 = np.empty((N, 2))
sol2[0] = z0

# Repeatedly call the `integrate` method to advance the
# solution to time t[k], and save the solution in sol[k].
k = 1
while solver.successful() and solver.t < t1:
    solver.integrate(t[k])
    sol2[k] = solver.y
    k += 1

# Plot the solution...
plt.plot(t, sol2[:,0], label='Gamma = 0.5')
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('t')
plt.ylabel('x')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import ode
import math


def fun(t,z ,gamma , w , delta , alfa , beta):
    """
    Right hand side of the differential equations
      dx/dt = -omega * y
      dy/dt = omega * x
    """
    x, y = z
    f = [y, gamma*math.cos(w*t)-delta*y-alfa*x-beta*x**3]
    return f

# Create an `ode` instance to solve the system of differential
# equations defined by `fun`, and set the solver method to 'dop853'.
solver = ode(fun)
solver.set_integrator('dop853')

# Give the value of omega to the solver. This is passed to
# `fun` when the solver calls it.
gamma = .65
w = 1.2
delta = 0.3
alfa = -1
beta = 1
solver.set_f_params(gamma,w,delta,alfa,beta)

# Set the initial value z(0) = z0.
t0 = 0.0
z0 = [1, 0]
solver.set_initial_value(z0, t0)

# Create the array `t` of time values at which to compute
# the solution, and create an array to hold the solution.
# Put the initial value in the solution array.
t1 = 70
N = 2000
t = np.linspace(t0, t1, N)
sol3 = np.empty((N, 2))
sol3[0] = z0

# Repeatedly call the `integrate` method to advance the
# solution to time t[k], and save the solution in sol[k].
k = 1
while solver.successful() and solver.t < t1:
    solver.integrate(t[k])
    sol3[k] = solver.y
    k += 1

# Plot the solution...
plt.plot(t, sol3[:,0], label='Gamma = 0.65')
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('t')
plt.ylabel('x')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the solution...

#plt.plot(wi2, zw2, label='x' , marker = ".")
#plt.plot(wi2, zw2, label='x', marker= ".", linestyle="none")

plt.figure(figsize=(12, 8))
#plt.plot(wi, zw, label="Beta = 0.04", marker= ".", linestyle="none")
plt.plot(sol[:,0], sol[:,1], label="Gamma = 0.20", marker= ".", linestyle="none")
#plt.plot(wi2, zw2, label="Beta = 0.0", marker= ".", linestyle="none")
#plt.plot(wi3, zw3, label="Beta = -0.003", marker= ".", linestyle="none")
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('Posición')
plt.ylabel("Velocidad")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the solution...

#plt.plot(wi2, zw2, label='x' , marker = ".")
#plt.plot(wi2, zw2, label='x', marker= ".", linestyle="none")

plt.figure(figsize=(12, 8))
#plt.plot(wi, zw, label="Beta = 0.04", marker= ".", linestyle="none")
plt.plot(sol1[:,0], sol1[:,1], label="Gamma = 0.35", marker= ".", linestyle="none")
#plt.plot(wi2, zw2, label="Beta = 0.0", marker= ".", linestyle="none")
#plt.plot(wi3, zw3, label="Beta = -0.003", marker= ".", linestyle="none")
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('Posición')
plt.ylabel("Velocidad")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the solution...

#plt.plot(wi2, zw2, label='x' , marker = ".")
#plt.plot(wi2, zw2, label='x', marker= ".", linestyle="none")

plt.figure(figsize=(12, 8))
#plt.plot(wi, zw, label="Beta = 0.04", marker= ".", linestyle="none")
plt.plot(sol2[:,0], sol2[:,1], label="Gamma = 0.50", marker= ".", linestyle="none")
#plt.plot(wi2, zw2, label="Beta = 0.0", marker= ".", linestyle="none")
#plt.plot(wi3, zw3, label="Beta = -0.003", marker= ".", linestyle="none")
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('Posición')
plt.ylabel("Velocidad")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot the solution...

#plt.plot(wi2, zw2, label='x' , marker = ".")
#plt.plot(wi2, zw2, label='x', marker= ".", linestyle="none")

plt.figure(figsize=(12, 8))
#plt.plot(wi, zw, label="Beta = 0.04", marker= ".", linestyle="none")
plt.plot(sol2[:,0], sol2[:,1], label="Gamma = 0.65", marker= ".", linestyle="none")
#plt.plot(wi2, zw2, label="Beta = 0.0", marker= ".", linestyle="none")
#plt.plot(wi3, zw3, label="Beta = -0.003", marker= ".", linestyle="none")
#plt.plot(t, sol[:,1], label='y')
plt.xlabel('Posición')
plt.ylabel("Velocidad")
plt.grid(True)
plt.legend()
plt.show()
